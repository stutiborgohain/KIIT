# %%
pip install selenium#installig selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver

# %%
driver=webdriver.Chrome('C:/Users/User/Desktop/chromedriver.exe')#installing driver for chrome

# %%
driver.get("https://www.flipkart.com/search?q=laptop&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off")#the link from where we want our data

# %%
<div class="_4rR01T">Lenovo Ideapad Slim 3i (2021) Core i5 11th Gen - (8 GB/512 GB SSD/Windows 10 Home) IdeaPad 3 15ITL6 Th...</div>
# Out:
#   File "<ipython-input-5-0b7d43d243e1>", line 1
#     <div class="_4rR01T">Lenovo Ideapad Slim 3i (2021) Core i5 11th Gen - (8 GB/512 GB SSD/Windows 10 Home) IdeaPad 3 15ITL6 Th...</div>
#     ^
# SyntaxError: invalid syntax

# %%
content=driver.page_source

# %%
content[:500]
# Out:
# '<html lang="en" class=" fonts-loaded"><head><script type="text/javascript" async="async" src="https://flipkart.d1.sc.omtrdc.net/id?d_visid_ver=1.5.4&amp;callback=s_c_il%5B0%5D._setAnalyticsFields&amp;mcorgid=17EB401053DAF4840A490D4C%40AdobeOrg&amp;mid=34573705944984342144169928578513853774"></script><script type="text/javascript" async="async" src="https://dpm.demdex.net/id?d_visid_ver=1.5.4&amp;d_rtbd=json&amp;d_ver=2&amp;d_orgid=17EB401053DAF4840A490D4C%40AdobeOrg&amp;d_nsid=0&amp;d_cb=s_c_il%'

# %%
from bs4 import BeautifulSoup as soup

# %%
d=soup(content,'html.parser')
#parser->breaking into smaller components(Split the text into smaller components)

# %%
print(type(d))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
print(d.prettify())
# Out:
# <html class="fonts-loaded" lang="en">
#  <head>
#   <script async="async" src="https://flipkart.d1.sc.omtrdc.net/id?d_visid_ver=1.5.4&amp;callback=s_c_il%5B0%5D._setAnalyticsFields&amp;mcorgid=17EB401053DAF4840A490D4C%40AdobeOrg&amp;mid=34573705944984342144169928578513853774" type="text/javascript">
#   </script>
#   <script async="async" src="https://dpm.demdex.net/id?d_visid_ver=1.5.4&amp;d_rtbd=json&amp;d_ver=2&amp;d_orgid=17EB401053DAF4840A490D4C%40AdobeOrg&amp;d_nsid=0&amp;d_cb=s_c_il%5B0%5D._setMarketingCloudFields" type="text/javascript">
#   </script>
#   <link href="https://rukminim1.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.3e7df7.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
# ...

# %%
d.children

# %%
d.findAll('div',attrs={'class':'_4rR01T'})#getting all the div that belong to the given class
# Out:
# [<div class="_4rR01T">Lenovo Ideapad Slim 5i Core i5 11th Gen - (16 GB/512 GB SSD/Windows 10 Home) 15 ITL 05 Thin and Light ...</div>,
#  <div class="_4rR01T">Lenovo Ideapad Slim 3i (2021) Core i5 11th Gen - (8 GB/512 GB SSD/Windows 10 Home) IdeaPad 3 15ITL6 Th...</div>,
#  <div class="_4rR01T">ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForce G...</div>,
#  <div class="_4rR01T">DELL Inspiron 3501 Core i5 11th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home) Inspiron 3501 Laptop</div>,
#  <div class="_4rR01T">HP Core i3 11th Gen - (8 GB/256 GB SSD/Windows 10 Home) 15s-FQ2075TU Thin and Light Laptop</div>,
#  <div class="_4rR01T">DELL Vostro Core i3 10th Gen - (4 GB/256 GB SSD/Windows 10 Home) Vostro 3401 Thin and Light Laptop</div>,
#  <div class="_4rR01T">APPLE MacBook Air M1 - (8 GB/256 GB SSD/Mac OS Big Sur) MGN63HN/A</div>,
# ...

# %%
#name
laptop=[]
for l in d.findAll('div',attrs={'class':'_4rR01T'}):
    #print(laptop)
    #print(l.append(l.get_text()))
    #print(l.get_text())
    laptop.append(l.get_text())

# %%
laptop
# Out:
# ['Lenovo Ideapad Slim 5i Core i5 11th Gen - (16 GB/512 GB SSD/Windows 10 Home) 15 ITL 05 Thin and Light ...',
#  'Lenovo Ideapad Slim 3i (2021) Core i5 11th Gen - (8 GB/512 GB SSD/Windows 10 Home) IdeaPad 3 15ITL6 Th...',
#  'ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForce G...',
#  'DELL Inspiron 3501 Core i5 11th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home) Inspiron 3501 Laptop',
#  'HP Core i3 11th Gen - (8 GB/256 GB SSD/Windows 10 Home) 15s-FQ2075TU Thin and Light Laptop',
#  'DELL Vostro Core i3 10th Gen - (4 GB/256 GB SSD/Windows 10 Home) Vostro 3401 Thin and Light Laptop',
#  'APPLE MacBook Air M1 - (8 GB/256 GB SSD/Mac OS Big Sur) MGN63HN/A',
#  'acer Aspire 7 Ryzen 5 Quad Core 3550H - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForce ...',
#  'HP 14s Core i3 11th Gen - (8 GB/256 GB SSD/Windows 10 Home) 14s- DY2501TU Thin and Light Laptop',
# ...

# %%
laptop[1]
# Out:
# 'Lenovo Ideapad Slim 3i (2021) Core i5 11th Gen - (8 GB/512 GB SSD/Windows 10 Home) IdeaPad 3 15ITL6 Th...'

# %%
#price
price=[]
for p in d.findAll('div',attrs={'class':"_30jeq3 _1_WHN1"}):
    price.append(p.get_text())

# %%
price
# Out:
# ['₹66,990',
#  '₹57,990',
#  '₹60,990',
#  '₹57,165',
#  '₹41,490',
#  '₹36,497',
#  '₹92,900',
#  '₹52,990',
#  '₹41,490',
#  '₹43,990',
#  '₹27,490',
#  '₹92,990',
#  '₹54,990',
#  '₹38,990',
#  '₹42,990',
#  '₹51,990',
#  '₹45,490',
#  '₹44,380',
#  '₹66,990',
#  '₹66,447',
#  '₹38,990',
#  '₹41,990',
#  '₹32,250',
#  '₹63,999']

# %%
import pandas as pd

# %%
df=pd.DataFrame([laptop,price])

# %%
df=df.T

# %%
df
# Out:
#                                                     0        1
# 0   Lenovo Ideapad Slim 5i Core i5 11th Gen - (16 ...  ₹66,990
# 1   Lenovo Ideapad Slim 3i (2021) Core i5 11th Gen...  ₹57,990
# 2   ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...  ₹60,990
# 3   DELL Inspiron 3501 Core i5 11th Gen - (8 GB/1 ...  ₹57,165
# 4   HP Core i3 11th Gen - (8 GB/256 GB SSD/Windows...  ₹41,490
# 5   DELL Vostro Core i3 10th Gen - (4 GB/256 GB SS...  ₹36,497
# 6   APPLE MacBook Air M1 - (8 GB/256 GB SSD/Mac OS...  ₹92,900
# 7   acer Aspire 7 Ryzen 5 Quad Core 3550H - (8 GB/...  ₹52,990
# 8   HP 14s Core i3 11th Gen - (8 GB/256 GB SSD/Win...  ₹41,490
# 9   Lenovo IdeaPad Slim 3i (2021) Core i3 11th Gen...  ₹43,990
# 10  HP 15s Athlon Dual Core - (4 GB/1 TB HDD/Windo...  ₹27,490
# 11  ASUS TUF Gaming A17 Ryzen 7 Octa Core 4800H - ...  ₹92,990
# 12  ASUS Vivobook Gaming Core i5 9th Gen - (8 GB/5...  ₹54,990
# 13  ASUS VivoBook 15 Core i3 10th Gen - (8 GB/1 TB...  ₹38,990
# ...

# %%
df.columns=['laptop','price']
df.index=[var for var in range(1,len(price)+1)]

# %%
df
# Out:
#                                                laptop    price
# 1   Lenovo Ideapad Slim 5i Core i5 11th Gen - (16 ...  ₹66,990
# 2   Lenovo Ideapad Slim 3i (2021) Core i5 11th Gen...  ₹57,990
# 3   ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...  ₹60,990
# 4   DELL Inspiron 3501 Core i5 11th Gen - (8 GB/1 ...  ₹57,165
# 5   HP Core i3 11th Gen - (8 GB/256 GB SSD/Windows...  ₹41,490
# 6   DELL Vostro Core i3 10th Gen - (4 GB/256 GB SS...  ₹36,497
# 7   APPLE MacBook Air M1 - (8 GB/256 GB SSD/Mac OS...  ₹92,900
# 8   acer Aspire 7 Ryzen 5 Quad Core 3550H - (8 GB/...  ₹52,990
# 9   HP 14s Core i3 11th Gen - (8 GB/256 GB SSD/Win...  ₹41,490
# 10  Lenovo IdeaPad Slim 3i (2021) Core i3 11th Gen...  ₹43,990
# 11  HP 15s Athlon Dual Core - (4 GB/1 TB HDD/Windo...  ₹27,490
# 12  ASUS TUF Gaming A17 Ryzen 7 Octa Core 4800H - ...  ₹92,990
# 13  ASUS Vivobook Gaming Core i5 9th Gen - (8 GB/5...  ₹54,990
# 14  ASUS VivoBook 15 Core i3 10th Gen - (8 GB/1 TB...  ₹38,990
# ...

# %%
#<div class="_3LWZlK">4.6<img src="..." class="_1wB99o"></div>

# %%
d.findAll('div',attrs={'class':"_3LWZlK"})
# Out:
# [<div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.7<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">3.9<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div>,
# ...

# %%
#rating

r=[]
for p in d.findAll('div',{'class':"_3LWZlK"}):
    r.append(p.get_text())
r
# Out:
# ['4.6',
#  '4.4',
#  '4.5',
#  '4.4',
#  '4.3',
#  '4.7',
#  '4.5',
#  '4.4',
#  '4.5',
#  '3.9',
#  '4.3',
#  '4.1',
#  '4.1',
#  '4.6',
#  '4.3',
#  '4.3',
#  '4.6',
#  '4.3',
#  '4.4',
#  '4.4',
#  '4.1',
#  '5',
#  '1',
#  '4.4',
#  '5',
#  '1',
#  '4.3',
#  '4',
#  '5',
#  '4.7',
#  '5',
#  '5',
#  '4.4',
#  '4',
#  '5']

# %%
df['price']
# Out:
# 1     ₹66,990
# 2     ₹57,990
# 3     ₹60,990
# 4     ₹57,165
# 5     ₹41,490
# 6     ₹36,497
# 7     ₹92,900
# 8     ₹52,990
# 9     ₹41,490
# 10    ₹43,990
# 11    ₹27,490
# 12    ₹92,990
# 13    ₹54,990
# 14    ₹38,990
# 15    ₹42,990
# 16    ₹51,990
# 17    ₹45,490
# 18    ₹44,380
# 19    ₹66,990
# 20    ₹66,447
# 21    ₹38,990
# 22    ₹41,990
# 23    ₹32,250
# 24    ₹63,999
# Name: price, dtype: object

# %% [markdown]
# # DAY2

# %%
job_title=input("enter the job")
city=input("enter the name of the city")
# Out:
# enter the jobdata scientist
# enter the name of the citymumbai

# %%
url="https://www.naukri.com/data-scientist-jobs-in-{city}?k={job_title}&l={city}"

# %%
import requests

# %%
data=requests.get(url)

# %%
data.status_code
# Out:
# 200

# %%
print(data.text)
# Out:
# <!DOCTYPE html> <html lang="en"> <head> <meta http-equiv="X-UA-Compatible" content="IE=Edge" /> <meta name="viewport" content="width=device-width,initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" /> <link rel="dns-prefetch preconnect" href="//static.naukri.com"> <link rel="dns-prefetch preconnect" href="//img.naukri.com"> <link rel="dns-prefetch preconnect" href="//logs.naukri.com"> <link rel="dns-prefetch preconnect" href="//lg.naukri.com"> <link rel="dns-prefetch" href="https://www.googletagmanager.com" /> <base href="//www.naukri.com" /> <link rel="manifest" href="./manifest.json"> <link rel="preload" as="style" href="//static.naukri.com/s/7/109/c/main.dc9a11bf.min.css"/> <link rel="preload" as="script" href="//static.naukri.com/s/7/109/j/main.a9c7559b.min.js"> <script>
#         window.ipAddress = "www.naukri.com";
#         window.DEBUG = true;
#         window.appId = 135;
#                     var isCrawler = false;
# ...

# %%
from selenium import webdriver

# %%
d=webdriver.Chrome('C:/Users/User/Desktop/chromedriver.exe')

# %%
d.get(url)

# %%
data=d.page_source
data
# Out:
# '<html lang="en"><head><title>Data Scientist Jobs In City - 4 Data Scientist Openings In City - Naukri.com</title><meta name="description" content="Apply To 4 Data Scientist Jobs In City On Naukri.com, India\'s No.1 Job Portal. Explore Data Scientist Job Openings In City Now!"><link rel="alternate" href="android-app://naukriApp.appModules.login/https/www.naukri.com/data-scientist-jobs-in-city"><link rel="canonical" href="https://www.naukri.com/data-scientist-jobs-in-city"><meta name="atdlayout" content="jobsearch"><meta name="robots" content="ALL"><meta name="classification" content="Jobs &amp; Career: Job Search, Apply Jobs, Post Jobs"><meta name="pragma" content="no-cache"><meta name="rating" content="general"><meta name="revisit-after" content="1 day"><meta name="distribution" content="GLOBAL"><meta name="resource-type" content="document"><meta name="author" content="www.naukri.com"><meta name="content-language" content="EN"><meta property="fb:app_id" content="171330469593307"><me
# ...

# %%
from bs4 import BeautifulSoup as soup

# %%
d=soup(data,'html.parser')
#parser->breaking into smaller components(Split the text into smaller components)

# %%
print(d.prettify())
# Out:
# <html lang="en">
#  <head>
#   <title>
#    Data Scientist Jobs In City - 4 Data Scientist Openings In City - Naukri.com
#   </title>
#   <meta content="Apply To 4 Data Scientist Jobs In City On Naukri.com, India's No.1 Job Portal. Explore Data Scientist Job Openings In City Now!" name="description"/>
#   <link href="android-app://naukriApp.appModules.login/https/www.naukri.com/data-scientist-jobs-in-city" rel="alternate"/>
#   <link href="https://www.naukri.com/data-scientist-jobs-in-city" rel="canonical"/>
#   <meta content="jobsearch" name="atdlayout"/>
#   <meta content="ALL" name="robots"/>
#   <meta content="Jobs &amp; Career: Job Search, Apply Jobs, Post Jobs" name="classification"/>
#   <meta content="no-cache" name="pragma"/>
#   <meta content="general" name="rating"/>
#   <meta content="1 day" name="revisit-after"/>
#   <meta content="GLOBAL" name="distribution"/>
#   <meta content="document" name="resource-type"/>
#   <meta content="www.naukri.com" name="author"/>
# ...

# %%
d=list(d.children)[0]
html=list(d.children)[0]

# %%
list(html.children)
# Out:
# [<title>Data Scientist Jobs In City - 4 Data Scientist Openings In City - Naukri.com</title>,
#  <meta content="Apply To 4 Data Scientist Jobs In City On Naukri.com, India's No.1 Job Portal. Explore Data Scientist Job Openings In City Now!" name="description"/>,
#  <link href="android-app://naukriApp.appModules.login/https/www.naukri.com/data-scientist-jobs-in-city" rel="alternate"/>,
#  <link href="https://www.naukri.com/data-scientist-jobs-in-city" rel="canonical"/>,
#  <meta content="jobsearch" name="atdlayout"/>,
#  <meta content="ALL" name="robots"/>,
#  <meta content="Jobs &amp; Career: Job Search, Apply Jobs, Post Jobs" name="classification"/>,
#  <meta content="no-cache" name="pragma"/>,
#  <meta content="general" name="rating"/>,
#  <meta content="1 day" name="revisit-after"/>,
#  <meta content="GLOBAL" name="distribution"/>,
#  <meta content="document" name="resource-type"/>,
#  <meta content="www.naukri.com" name="author"/>,
# ...

# %%
list(html.children)[15]
# Out:
# <meta content="2021 Naukri.com" name="copyright"/>

# %%
list(html.children)[:15]
# Out:
# [<title>Data Scientist Jobs In City - 4 Data Scientist Openings In City - Naukri.com</title>,
#  <meta content="Apply To 4 Data Scientist Jobs In City On Naukri.com, India's No.1 Job Portal. Explore Data Scientist Job Openings In City Now!" name="description"/>,
#  <link href="android-app://naukriApp.appModules.login/https/www.naukri.com/data-scientist-jobs-in-city" rel="alternate"/>,
#  <link href="https://www.naukri.com/data-scientist-jobs-in-city" rel="canonical"/>,
#  <meta content="jobsearch" name="atdlayout"/>,
#  <meta content="ALL" name="robots"/>,
#  <meta content="Jobs &amp; Career: Job Search, Apply Jobs, Post Jobs" name="classification"/>,
#  <meta content="no-cache" name="pragma"/>,
#  <meta content="general" name="rating"/>,
#  <meta content="1 day" name="revisit-after"/>,
#  <meta content="GLOBAL" name="distribution"/>,
#  <meta content="document" name="resource-type"/>,
#  <meta content="www.naukri.com" name="author"/>,
# ...

# %%
list(html.children)[-15:]
# Out:
# [<link crossorigin="anonymous" href="//static.naukri.com/s/7/109/c/follow-group.f978a281.min.css" rel="stylesheet" type="text/css"/>,
#  <script charset="utf-8" crossorigin="anonymous" src="//static.naukri.com/s/7/109/j/follow-group.30091cf6.min.js"></script>,
#  <link crossorigin="anonymous" href="//static.naukri.com/s/7/109/c/jobTuple.cb83445c.min.css" rel="stylesheet" type="text/css"/>,
#  <script charset="utf-8" crossorigin="anonymous" src="//static.naukri.com/s/7/109/j/jobTuple.43f0a6d7.min.js"></script>,
#  <link crossorigin="anonymous" href="//static.naukri.com/s/7/109/c/pagination.09eae69e.min.css" rel="stylesheet" type="text/css"/>,
#  <script charset="utf-8" crossorigin="anonymous" src="//static.naukri.com/s/7/109/j/pagination.cf49553c.min.js"></script>,
#  <link crossorigin="anonymous" href="//static.naukri.com/s/7/109/c/FFBottom.15cc7065.min.css" rel="stylesheet" type="text/css"/>,
# ...

# %%
for var in range(len(list(d.children))):
    print(var+1,list(d.children)[var])
    print()
    print()
# Out:
# 1 <head><title>Data Scientist Jobs In City - 4 Data Scientist Openings In City - Naukri.com</title><meta content="Apply To 4 Data Scientist Jobs In City On Naukri.com, India's No.1 Job Portal. Explore Data Scientist Job Openings In City Now!" name="description"/><link href="android-app://naukriApp.appModules.login/https/www.naukri.com/data-scientist-jobs-in-city" rel="alternate"/><link href="https://www.naukri.com/data-scientist-jobs-in-city" rel="canonical"/><meta content="jobsearch" name="atdlayout"/><meta content="ALL" name="robots"/><meta content="Jobs &amp; Career: Job Search, Apply Jobs, Post Jobs" name="classification"/><meta content="no-cache" name="pragma"/><meta content="general" name="rating"/><meta content="1 day" name="revisit-after"/><meta content="GLOBAL" name="distribution"/><meta content="document" name="resource-type"/><meta content="www.naukri.com" name="author"/><meta content="EN" name="content-language"/><meta content="171330469593307" property="fb:app_id"/><meta
# ...

# %%
print(html.prettify())
# Out:
# <head>
#  <title>
#   Data Scientist Jobs In City - 4 Data Scientist Openings In City - Naukri.com
#  </title>
#  <meta content="Apply To 4 Data Scientist Jobs In City On Naukri.com, India's No.1 Job Portal. Explore Data Scientist Job Openings In City Now!" name="description"/>
#  <link href="android-app://naukriApp.appModules.login/https/www.naukri.com/data-scientist-jobs-in-city" rel="alternate"/>
#  <link href="https://www.naukri.com/data-scientist-jobs-in-city" rel="canonical"/>
#  <meta content="jobsearch" name="atdlayout"/>
#  <meta content="ALL" name="robots"/>
#  <meta content="Jobs &amp; Career: Job Search, Apply Jobs, Post Jobs" name="classification"/>
#  <meta content="no-cache" name="pragma"/>
#  <meta content="general" name="rating"/>
#  <meta content="1 day" name="revisit-after"/>
#  <meta content="GLOBAL" name="distribution"/>
#  <meta content="document" name="resource-type"/>
#  <meta content="www.naukri.com" name="author"/>
# ...

# %%
d=list(d.children)[0]
html=list(d.children)
html
# Out:
# [<title>Data Scientist Jobs In City - 4 Data Scientist Openings In City - Naukri.com</title>,
#  <meta content="Apply To 4 Data Scientist Jobs In City On Naukri.com, India's No.1 Job Portal. Explore Data Scientist Job Openings In City Now!" name="description"/>,
#  <link href="android-app://naukriApp.appModules.login/https/www.naukri.com/data-scientist-jobs-in-city" rel="alternate"/>,
#  <link href="https://www.naukri.com/data-scientist-jobs-in-city" rel="canonical"/>,
#  <meta content="jobsearch" name="atdlayout"/>,
#  <meta content="ALL" name="robots"/>,
#  <meta content="Jobs &amp; Career: Job Search, Apply Jobs, Post Jobs" name="classification"/>,
#  <meta content="no-cache" name="pragma"/>,
#  <meta content="general" name="rating"/>,
#  <meta content="1 day" name="revisit-after"/>,
#  <meta content="GLOBAL" name="distribution"/>,
#  <meta content="document" name="resource-type"/>,
#  <meta content="www.naukri.com" name="author"/>,
# ...

# %%
html
# Out:
# [<title>Data Scientist Jobs In City - 4 Data Scientist Openings In City - Naukri.com</title>,
#  <meta content="Apply To 4 Data Scientist Jobs In City On Naukri.com, India's No.1 Job Portal. Explore Data Scientist Job Openings In City Now!" name="description"/>,
#  <link href="android-app://naukriApp.appModules.login/https/www.naukri.com/data-scientist-jobs-in-city" rel="alternate"/>,
#  <link href="https://www.naukri.com/data-scientist-jobs-in-city" rel="canonical"/>,
#  <meta content="jobsearch" name="atdlayout"/>,
#  <meta content="ALL" name="robots"/>,
#  <meta content="Jobs &amp; Career: Job Search, Apply Jobs, Post Jobs" name="classification"/>,
#  <meta content="no-cache" name="pragma"/>,
#  <meta content="general" name="rating"/>,
#  <meta content="1 day" name="revisit-after"/>,
#  <meta content="GLOBAL" name="distribution"/>,
#  <meta content="document" name="resource-type"/>,
#  <meta content="www.naukri.com" name="author"/>,
# ...

# %%
articles=html[5].findChild('article')
print(articles)
# Out:
# None

# %%
for var in range(len(articles.find_next_siblings())):
    print(articles.find_next_siblings()[var].get_text())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-141-975853c09b60> in <module>
# ----> 1 for var in range(len(articles.find_next_siblings())):
#       2     print(articles.find_next_siblings()[var].get_text())
#
# AttributeError: 'NoneType' object has no attribute 'find_next_siblings'

# %%
<article class="jobTuple bgWhite br4 mb-8" data-job-id="040721000317"><div class="jobTupleHeader"><div class="info fleft"><a class="title fw500 ellipsis" href="https://www.naukri.com/job-listings-data-scientist-data-analyst-business-analyst-inflexion-analytix-private-limited-pune-delhi-ncr-mumbai-all-areas-0-to-3-years-040721000317?src=seo_srp&amp;sid=16261443432513609&amp;xp=1&amp;px=1" title="Data Scientist/Data Analyst /Business Analyst" target="_blank">Data Scientist/Data Analyst /Business Analyst</a><div class="mt-7 companyInfo subheading lh16"><a href="https://www.naukri.com/inflexion-analytix-jobs-careers-3958080" class="subTitle ellipsis fleft" target="_blank" title="Inflexion Analytix Private Limited">Inflexion Analytix Private Limited</a></div><ul class="mt-7"><li class="fleft grey-text br2 placeHolderLi experience"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-experience"></i><span title="0-3 Yrs " class="ellipsis fleft fs12 lh16 ">0-3 Yrs</span></li><li class="fleft grey-text br2 placeHolderLi salary"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-rupee"></i><span title="3,50,000 - 4,50,000 PA. " class="ellipsis fleft fs12 lh16 ">3,50,000 - 4,50,000 PA.</span></li><li class="fleft grey-text br2 placeHolderLi location"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-location"></i><span title="Pune, Delhi / NCR, Mumbai (All Areas) " class="ellipsis fleft fs12 lh16 ">Pune, Delhi / NCR, Mumbai (All Areas)</span></li></ul></div></div><div class="job-description fs12 grey-text"><i class="fleft icon-16 lh16 mr-4 naukicon naukicon-desc"></i> Location: Pune /Mumbai/Delhi/Noida/KolkattaGreetings from CAIA - Center for Artificial ...</div><ul class="tags has-description"><li class="fleft fs12 grey-text lh16 dot">IT Skills</li><li class="fleft fs12 grey-text lh16 dot">Python</li><li class="fleft fs12 grey-text lh16 dot">Data Science</li><li class="fleft fs12 grey-text lh16 dot">Machine Learning</li><li class="fleft fs12 grey-text lh16 dot">Artificial Intelligence</li><li class="fleft fs12 grey-text lh16 dot">Cloud</li><li class="fleft fs12 grey-text lh16 dot">Big Data</li><li class="fleft fs12 grey-text lh16 dot">Business Intelligence</li></ul><div class="jobTupleFooter mt-20"><div class="jobType type fleft br2 mr-8"><i class="fleft mr-4 fs11 naukicon naukicon-hot-jobs"></i><span class="fleft fw500">HOT JOB</span></div><div class="type br2 fleft grey"><i class="fleft mr-4 fs11 naukicon naukicon-history"></i><span class="fleft fw500">8 Days Ago</span></div><div class="saveJobContainer fright grey-text save"><i class="fleft mr-4 icon-16 lh16 naukicon naukicon-save"></i><span class="saveSpn fs12">save</span></div></div></article>
# Out:
#   File "<ipython-input-66-cef050b5f4a8>", line 1
# ...

# %%
soup.find_all('article',attrs={'class':'jobTuple bgWhite br4 mb-8'})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-1da379a56956> in <module>
# ----> 1 soup.find_all('article',attrs={'class':'jobTuple bgWhite br4 mb-8'})
#
# ~\anaconda3\lib\site-packages\bs4\element.py in find_all(self, name, attrs, recursive, text, limit, **kwargs)
#    1783         :rtype: bs4.element.ResultSet
#    1784         """
# -> 1785         generator = self.descendants
#    1786         if not recursive:
#    1787             generator = self.children
#
# AttributeError: 'str' object has no attribute 'descendants'
